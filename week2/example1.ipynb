# %%
from __future__ import division, print_function, unicode_literals
import numpy as np
import matplotlib.pyplot as plt
# Temp (F degree)
X = np.array([[194.5, 194.3, 197.9, 198.4, 199.4, 199.9, 200.9, 201.1, 201.4, 201.3, 20, \
3.6, 204.6, 209.5, 208.6, 210.7, 211.9, 212.2]])
# Press (Atm)
y = np.array([[20.79,20.79,22.4,22.67,23.15,23.35,23.89,23.99,24.02,24.01,25.14,26.57,2, \
8.49,27.76,29.04,29.88,30.06]])
# Visualize data
plt.plot(X, y, 'ro')
plt.axis([193, 213, 19, 31])
plt.xlabel('Temperature (F)')
plt.ylabel('Pressure (Atm)')
plt.show()

# %%
# Building Xbar
one = np.ones((X.shape[0], 1))
Xbar = np.concatenate((one, X), axis = 1)

# Calculating weights of the fitting line
A = np.dot(Xbar.T, Xbar)
b = np.dot(Xbar.T, y)
w = np.dot(np.linalg.pinv(A), b)
print('w = ', w)
# Preparing the fitting line
w_0 = w[0][0]
w_1 = w[1][0]
x0 = np.linspace(193, 213, 2)
y0 = w_0 + w_1*x0

# Drawing the fitting line
plt.plot(X.T, y.T, 'ro') # data
plt.plot(x0, y0) # the fitting line
plt.axis([193, 213, 19, 31])
plt.xlabel('Temperature (F)')
plt.ylabel('Pressure (Atm)')
plt.show()
# Out:
# w =  [[3.15133684e-05 3.15133684e-05 3.39537976e-05 3.43630621e-05
#   3.50906435e-05 3.53938024e-05 3.62123314e-05 3.63639109e-05
#   3.64093847e-05 3.63942268e-05 3.81070746e-05 4.02746608e-05
#   3.03158907e-06 1.28690956e-05 4.20784563e-05 4.40186733e-05
#   4.52919407e-05 4.55647837e-05]
#  [6.12935014e-03 6.12935014e-03 6.60401362e-03 6.68361557e-03
#   6.82513015e-03 6.88409456e-03 7.04329846e-03 7.07278066e-03
#   7.08162532e-03 7.07867710e-03 7.41182600e-03 7.83342152e-03
#   5.89644074e-04 2.50303909e-03 8.18425974e-03 8.56163195e-03
#   8.80928246e-03 8.86235043e-03]
#  [6.12304747e-03 6.12304747e-03 6.59722286e-03 6.67674296e-03
#   6.81811202e-03 6.87701580e-03 7.03605599e-03 7.06550788e-03
#   7.07434345e-03 7.07139826e-03 7.40420459e-03 7.82536659e-03
#   5.89037756e-04 2.50046527e-03 8.17584405e-03 8.55282821e-03
#   8.80022407e-03 8.85323747e-03]
#  [6.23649560e-03 6.23649560e-03 6.71945654e-03 6.80044998e-03
# ...
